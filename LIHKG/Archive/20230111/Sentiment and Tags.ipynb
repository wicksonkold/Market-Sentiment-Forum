# %%
from snownlp import SnowNLP
import pandas as pd
import time
from datetime import timedelta, date, datetime
from dateutil.relativedelta import relativedelta

import pycantonese
from pycantonese.word_segmentation import Segmenter
from collections import Counter

# %% [markdown]
# ### PYCANTONESE

# %%
# %%time
total_segmented_word = list()
segmented_word = list()

#use the customized word list for the nlp
segmenter = Segmenter(max_word_length=8)

comment_context = ['係升返少少， 但仲未去到2019個價， 真係好癲','用左成年去跌，估唔到升得咁快，姐係其實大家真係好多錢，睇下買唔買然而#hehe# 邊到有移民潮走資潮']

for idx, context in enumerate(comment_context):
    #segment the sentence
    temp_result = pycantonese.segment(context, cls=segmenter)
    #temp_result = pycantonese.pos_tag(temp_result)
    print("Orginal:\n",context)
    print("\nResult:\n",temp_result)
    print('='*50)
'''
    for word, pos in temp_result:
        if pos == 'ADJ' or pos == 'NOUN' or pos == 'VERB':
'''
# Out:
# Orginal:
#  係升返少少， 但仲未去到2019個價， 真係好癲
#
# Result:
#  ['係', '升', '返', '少少', '，', '但', '仲未', '去到', '2019', '個', '價', '，', '真係', '好', '癲']
# ==================================================
# Orginal:
#  用左成年去跌，估唔到升得咁快，姐係其實大家真係好多錢，睇下買唔買然而#hehe# 邊到有移民潮走資潮
#
# Result:
#  ['用', '左', '成年', '去', '跌', '，', '估', '唔', '到', '升', '得', '咁快', '，', '姐', '係', '其實', '大家', '真係', '好多', '錢', '，', '睇下', '買', '唔', '買', '然而', '#', 'hehe', '#', '邊', '到', '有', '移民潮', '走資', '潮']
# ==================================================
# Wall time: 3.51 s
# "\n    for word, pos in temp_result:\n        if pos == 'ADJ' or pos == 'NOUN' or pos == 'VERB':\n"

# %% [markdown]
# ### SnowNLP

# %%
for idx, context in enumerate(comment_context):
    s = SnowNLP(context)
    word = s.words
    print("Orginal:\n",context)
    print("\nResult:\n",word)
    print("="*50)
# Out:
# Orginal:
#  係升返少少， 但仲未去到2019個價， 真係好癲
#
# Result:
#  ['係升', '返少', '少', '，', '但', '仲', '未', '去', '到', '2019', '個', '價', '，', '真', '係', '好', '癲']
# ==================================================
# Orginal:
#  用左成年去跌，估唔到升得咁快，姐係其實大家真係好多錢，睇下買唔買然而#hehe# 邊到有移民潮走資潮
#
# Result:
#  ['用', '左', '成年', '去跌', '，', '估', '唔', '到', '升得', '咁快', '，', '姐', '係', '其', '實', '大', '家', '真', '係', '好', '多', '錢', '，', '睇', '下', '買', '唔', '買', '然而', '#hehe#', '邊到', '有', '移民', '潮', '走', '資潮']
# ==================================================

# %%
#Over 50 = positive lower than 50 = negative 
for idx, context in enumerate(comment_context):
    s = SnowNLP(context)
    sentiments = s.sentiments
    print("Orginal:\n",context)
    print("\nResult:\n",sentiments)
    print('='*50)
# Out:
# Orginal:
#  係升返少少， 但仲未去到2019個價， 真係好癲
#
# Result:
#  0.743106931949525
# ==================================================
# Orginal:
#  用左成年去跌，估唔到升得咁快，姐係其實大家真係好多錢，睇下買唔買然而#hehe# 邊到有移民潮走資潮
#
# Result:
#  0.9898619250983283
# ==================================================

# %% [markdown]
# ### LIHKG Title with SnowNLP Sentiment

# %%
df_thread_log = pd.read_excel('LIHKG_Thread_Log.xlsx')
threads_title = df_thread_log["Thread Title"].values.tolist()

# %%
#Over 50 = positive lower than 50 = negative 
for idx, title in enumerate(threads_title):
    s = SnowNLP(title)
    sentiments = s.sentiments
    print("Orginal:\n",title)
    print("\nResult:\n",sentiments)
    print('='*50)
# Out:
# Orginal:
#  viu邊度黃呀？mirror邊度黃呀？反tvb就叫黃？鬼打鬼渣喎，你咪又係撐緊藍？
#
# Result:
#  0.990017213970043
# ==================================================
# Orginal:
#  中東阿布扎比銀行考慮收購渣打
#
# Result:
#  0.8246773465949826
# ==================================================
# Orginal:
#  渣打定期5.25
#
# Result:
#  0.16849244223532023
# ==================================================
# Orginal:
#  邊間渣打多靚女推介
#
# Result:
#  0.5399458887330778
# ==================================================
# Orginal:
#  渣打比人盜用左條數係唔係要找??
#
# Result:
#  0.8093406835005924
# ==================================================
# Orginal:
#  渣打：比特幣將暴跌至5000美元，金價衝上3000美元
#
# Result:
#  0.4966543571168609
# ==================================================
# Orginal:
#  「整渣打網上銀行手機Apps嘅工程師麻煩入一入嚟」
#
# Result:
#  0.006163266344170082
# ==================================================
# Orginal:
#  渣打拎外幣方法
#
# Result:
#  0.06543543085590331
# ==================================================
# Orginal:
#  渣打幾時肯出大promo吸新客 (me)
#
# Result:
#  0.12583426378409657
# ==================================================
# Orginal:
#  渣打個電話究竟打得通未
#
# Result:
#  0.05285050467990837
# ==================================================
# Orginal:
#  屌你老母渣打
#
# Result:
#  0.44767845850986676
# ==================================================
# Orginal:
#  突發！張渣打信用卡俾人碌左萬鳩幾蚊！！
#
# Result:
#  0.10748516628821925
# ==================================================
# Orginal:
#  渣打：沒有證據顯示本行出現個人資料外洩 下周開始為受影響客戶進行退款
#
# Result:
#  0.0028375078484494942
# ==================================================
# Orginal:
#  渣打：近日信用卡可疑交易事件中，只有1%帳戶受影響，下星期一起陸續安排退款，並無證據顯示銀行出現個人資料外洩
#
# Result:
#  3.7325517942998765e-05
# ==================================================
# Orginal:
#  點解渣打ATM入錢冇得即時更新信用卡餘額
#
# Result:
#  0.008894991232104132
# ==================================================
# Orginal:
#  渣打：客戶信用卡被盜用毋須責任  呼籲不用急於致電查詢
#
# Result:
#  0.0033945384556448577
# ==================================================
# Orginal:
#  渣打一事又一次引証香港人果種一窩蜂肉酸性格
#
# Result:
#  0.7717750952611676
# ==================================================
# Orginal:
#  渣打係咪收左皮
#
# Result:
#  0.9070096277956495
# ==================================================
# Orginal:
#  屌你M記個APP仲廢過渣打個APP
#
# Result:
#  0.020662188119693337
# ==================================================
# Orginal:
#  渣打國泰萬事達卡被盜用 料受程式化銀行識別碼襲擊
#
# Result:
#  0.0782599080490396
# ==================================================
# Orginal:
#  渣打真係慘 意外就係意料之外 成班廢人係度唔知驚乜
#
# Result:
#  0.9778964706848876
# ==================================================
# Orginal:
#  渣打連個網都停埋咩玩法
#
# Result:
#  0.5942301030399689
# ==================================================
# Orginal:
#  渣打信用卡疑被集體盜用 熱線長期唔通全城怒「虎」！ 男苦主被盜碌逾$17000報警求助！｜Channel C HK
#
# Result:
#  0.0015138119097940494
# ==================================================
# Orginal:
#  渣打信用卡部門職員，你問我答
#
# Result:
#  0.0006761810556122905
# ==================================================
# Orginal:
#  渣打信用卡疑被盜用　消委會昨日至今接4宗投訴
#
# Result:
#  0.02229692686617879
# ==================================================
# Orginal:
#  渣打就即刻有人報, CITI就冇人理 :o):o):o)
#
# Result:
#  0.10900217264176004
# ==================================================
# Orginal:
#  渣打信用卡客戶懷疑被大規模盜用 官方最新回應：確定非授權交易可獲退款！
#
# Result:
#  0.00015338738917358707
# ==================================================
# Orginal:
#  渣打癲𨶙到好得戚係Facebook順便sell佢地個SC Mobile好方便
#
# Result:
#  0.5824382535206393
# ==================================================
# Orginal:
#  [多謝你班恐懼撚] 渣打信用卡
#
# Result:
#  0.16233726284168404
# ==================================================
# Orginal:
#  渣打估比特幣或暴跌至5000美元
#
# Result:
#  0.778170544568886
# ==================================================
# Orginal:
#  渣打 呢間垃圾，永不錄用
#
# Result:
#  0.04169143372926054
# ==================================================
# Orginal:
#  有無人用渣打，大件事
#
# Result:
#  0.4200641843226419
# ==================================================
# Orginal:
#  渣打個結餘update唔到
#
# Result:
#  0.02472219871516612
# ==================================================
# Orginal:
#  屌你老母渣打
#
# Result:
#  0.44767845850986676
# ==================================================
# Orginal:
#  渣打e-banking又做乜撚野呀
#
# Result:
#  0.3409174705246163
# ==================================================
# Orginal:
#  渣打信用卡比人碌咗錢 (2) - 即用App lock卡
#
# Result:
#  0.004603467328925248
# ==================================================
# Orginal:
#  垃圾渣打被集體盜用
#
# Result:
#  0.030353906244217077
# ==================================================
# Orginal:
#  渣打cs句耐心等候真係難聽過粗口
#
# Result:
#  0.5683325561447763
# ==================================================
# Orginal:
#  有冇人同渣打DBS申請過drp
#
# Result:
#  0.46242290941582687
# ==================================================
# Orginal:
#  家母渣打户口被人封咗…佢寄信嚟先知
#
# Result:
#  0.6813199327607433
# ==================================================
# Orginal:
#  ？渣打：比特幣明年或下探 5 千美元
#
# Result:
#  0.9637142953618923
# ==================================================
# Orginal:
#  渣華、蟒蛇、丙、丙加加、丙井、矣打、基本、帕斯卡
#
# Result:
#  0.42446769068443235
# ==================================================
# Orginal:
#  有無人更新完渣打個APP之後登入唔到
#
# Result:
#  0.017654926430249906
# ==================================================
# Orginal:
#  （求救）申請結戶文件比渣打一拖再拖可以點做..
#
# Result:
#  0.11043518734844404
# ==================================================
# Orginal:
#  渣古番更衣室會唔會比人打？
#
# Result:
#  0.04062390518610004
# ==================================================
# Orginal:
#  有冇人住近渣華道，想搵人book 場打壁球
#
# Result:
#  0.2876297219428746
# ==================================================
# Orginal:
#  渣打香港上調H按封頂 實際息率為3.375%
#
# Result:
#  0.020626897058056093
# ==================================================
# Orginal:
#  有冇人做緊或做緊渣打loan sales 呀
#
# Result:
#  0.9845931696706895
# ==================================================
# Orginal:
#  渣打股票又login 唔到
#
# Result:
#  0.8140701019902229
# ==================================================
# Orginal:
#  會後吐真言 渣打溫拓斯：香港防疫措施嚇寺外資
#
# Result:
#  0.7735053496994196
# ==================================================
# Orginal:
#  渣打smart卡消失？
#
# Result:
#  0.3097904601870486
# ==================================================
# Orginal:
#  渣打、恒生：港元儲蓄戶口利率上調至0.375厘
#
# Result:
#  0.03573137547852756
# ==================================================
# Orginal:
#  渣打smart crad迎新好麻煩架！各巴絲小心！
#
# Result:
#  0.61225805836122
# ==================================================
# Orginal:
#  如果Calvin老師出道做哥手會唔會屌打左林家謙 MC果渣
#
# Result:
#  0.3234707213197826
# ==================================================
# Orginal:
#  彭博女權記者轟金融峰會87%為男性 恒生渣打一姐躺著也中槍
#
# Result:
#  0.9814299662664255
# ==================================================
# Orginal:
#  我思疑匯豐同渣打一定仲有為李家超等人提供銀行服務
#
# Result:
#  0.03345014418551029
# ==================================================
# Orginal:
#  Login 唔到渣打 Mobile banking
#
# Result:
#  0.5678383114913966
# ==================================================
# Orginal:
#  渣打滙控拉隊來港開高層會議 趁出席金融峰會 表態支持復常
#
# Result:
#  0.030299514829241425
# ==================================================
# Orginal:
#  施政報告一出，渣打一姐都走佬
#
# Result:
#  0.36572248462439105
# ==================================================
# Orginal:
#  開渣打張虛擬信用卡就有NOWE世界杯睇，點睇？
#
# Result:
#  0.6362708088081227
# ==================================================
# Orginal:
#  睇嚟揸兜今日好唔掂喎⋯⋯
#
# Result:
#  0.29724153935908626
# ==================================================
# Orginal:
#  揸兜信用卡比人碌到錢
#
# Result:
#  0.07561126853905642
# ==================================================
# Orginal:
#  mpf咁撚樣搞 係咪以後65歲後個個揸兜？
#
# Result:
#  0.011323261722125166
# ==================================================
# Orginal:
#  中東阿布扎比銀行考慮收購渣打
#
# Result:
#  0.8246773465949826
# ==================================================
# Orginal:
#  「整渣打網上銀行手機Apps嘅工程師麻煩入一入嚟」
#
# Result:
#  0.006163266344170082
# ==================================================
